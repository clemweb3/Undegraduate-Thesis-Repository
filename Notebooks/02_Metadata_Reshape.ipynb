# %% [markdown]
# This notebook focuses on reshaping metadata files (the Excel dictionaries that describe survey variables). It extracts the Sheet 1 and Sheet 2 Metadata (for context, there are a total of two metadata sheets available for all survey months for decoding purposes) across all years/months and saves them into a new folder (NEW Metadata Sheet 1 CSV's and NEW Metadata Sheet 2 CSV's).
#
# - it loads metadata files from the inventory.
#
# - It extracts extended variable names and descriptions from Sheet 1 (columns E and F).
#
# - It cleans empty rows and trims whitespace.
#
# - It saves reshaped metadata into a dedicated folder (data/interim/metadata_sheet1/).
#
# - Batch process: Load raw metadata, reshape variables, save clean CSVs.
#
# - Verification: Compare raw vs reshaped counts to ensure no variables or descriptions were lost.
#
# **INTENT:**  Metadata often contains empty spaces and inconsistent formatting, which show up as NaN in analysis. By reshaping metadata first, we ensure that variable names and descriptions are clean and reliable.

# %% [markdown]
# #### Imports and Setup

# %%
import pandas as pd
import json
from pathlib import Path
import os

# Load settings
with open(Path("./data/interim/config.json")) as f:
    cfg = json.load(f)

BASE_PATH = Path(cfg["BASE_PATH"])
INTERIM_DIR = Path(cfg["INTERIM_DIR"])

print("Settings loaded.")

# Load inventory (already built in 01_Inventory.ipynb)
with open(INTERIM_DIR / "inventory.json") as f:
    inventory = json.load(f)

print("Inventory loaded. Years available:", list(inventory.keys()))

# Create NEW local subfolder for reshaped metadata outputs
metadata_out = INTERIM_DIR / "NEW_metadata_sheet1"
metadata_out.mkdir(parents=True, exist_ok=True)

print("Reshaped metadata will be temporarily saved to:", metadata_out)
# Out:
# Settings loaded.
# Inventory loaded. Years available: ['2018', '2019', '2022', '2023', '2024']
# Reshaped metadata will be temporarily saved to: C:\Users\SHANIA\Downloads\Preprocessing\Notebooks\data\interim\NEW_metadata_sheet1

# %% [markdown]
# #### Load dataset (optimized)

# %%
def load_dataset(year, month, filetype="survey", sheet_number=None):
    """
    Load a dataset from the inventory.
    - year: str, e.g., "2018"
    - month: str, e.g., "January"
    - filetype: "survey" or "metadata"
    - sheet_number: 0 (Sheet 1) or 1 (Sheet 2) for metadata
    """
    file_info = next((f for f in inventory[year][month] if f["filetype"] == filetype), None)
    if not file_info:
        raise ValueError(f"No {filetype} file found for {month} {year}")

    file_path = BASE_PATH / year / file_info["filename"]

    if filetype == "survey":
        return pd.read_csv(file_path, low_memory=False)
    if sheet_number is not None:
        return pd.read_excel(file_path, sheet_name=sheet_number, engine="openpyxl")
    return pd.read_excel(file_path, engine="openpyxl")

# %% [markdown]
# #### Preview raw metadata Sheet 1 (before automation)

# %%
# Load the first sheet of January 2018 metadata
january_2018_metadata_sheet1 = load_dataset("2018", "January", "metadata", sheet_number=0)

# View the first few rows
print("=== January 2018 Metadata Sheet 1 (Raw) ===")
display(january_2018_metadata_sheet1.head())
# Out:
# === January 2018 Metadata Sheet 1 (Raw) ===
#    QUEST  Questionnaire Unnamed: 2  Unnamed: 3 Unnamed: 4  \
# 0    NaN            NaN      _IDS0  (Id Items)        NaN
# 1    NaN            NaN        NaN         NaN     PUFREG
# 2    NaN            NaN        NaN         NaN     PUFPRV
# 3    NaN            NaN        NaN         NaN   PUFPRRCD
# 4    NaN            NaN        NaN         NaN   PUFHHNUM
#
#                            Unnamed: 5
# 0                                 NaN
# 1                              Region
# 2                            Province
# 3                     Province Recode
# 4  Household Unique Sequential Number

# %% [markdown]
# ### Sheet 1 Metadata Reshape Automation

# %% [markdown]
# #### Extract variables

# %%
def extract_variables(df):
    """
    Extract variable names and descriptions from metadata Sheet 1.
    Columns E and F (index 4 and 5) contain variable codes and descriptions.
    Returns a clean DataFrame with ['Variable', 'Description'].
    """
    df_vars = df.iloc[:, 4:6].copy()
    df_vars.columns = ['Variable', 'Description']

    # Drop empty rows
    df_vars = df_vars[df_vars['Variable'].notna() & (df_vars['Variable'].astype(str).str.strip() != '')]

    # Clean whitespace
    df_vars['Variable'] = df_vars['Variable'].astype(str).str.strip()
    df_vars['Description'] = df_vars['Description'].astype(str).str.strip()

    return df_vars.reset_index(drop=True)

# %% [markdown]
# #### Batch process (year by year option)

# %%
def batch_process_sheet1_metadata(inventory, base_output_path, years=None):
    """
    Process metadata Sheet 1 for selected years.
    Saves reshaped CSVs into NEW_metadata_sheet1 folder.
    """
    success_count, failure_count, skipped_count = 0, 0, 0
    errors_log = []

    main_folder_path = os.path.join(base_output_path, "data", "interim", "NEW_metadata_sheet1")
    os.makedirs(main_folder_path, exist_ok=True)

    print("--- STARTING BATCH PROCESS ---")
    print(f"Target Directory: {main_folder_path}")
    print("-" * 50)

    # Limit to selected years if provided
    years_to_process = years if years else inventory.keys()

    for year in years_to_process:
        year_folder_path = os.path.join(main_folder_path, year)
        os.makedirs(year_folder_path, exist_ok=True)

        for month, files_list in inventory[year].items():
            if month == "Unmatched":
                continue

            has_metadata = any(f.get('filetype') == 'metadata' for f in files_list)
            if not has_metadata:
                skipped_count += 1
                continue

            try:
                raw_df = load_dataset(year, month, "metadata", 0)
                clean_df = extract_variables(raw_df)

                filename = f"Sheet1_{month}_{year}.csv"
                full_save_path = os.path.join(year_folder_path, filename)
                clean_df.to_csv(full_save_path, index=False)

                print(f"[OK] Saved: {year}/{filename}")
                success_count += 1

            except Exception as e:
                print(f"[ERROR] Failed {month} {year}: {e}")
                errors_log.append(f"{month} {year}: {str(e)}")
                failure_count += 1

    print("\n=== PROCESSING SUMMARY REPORT ===")
    print(f"Total Successfully Saved: {success_count}")
    print(f"Total Failed:             {failure_count}")
    print(f"Total Skipped (No File):  {skipped_count}")
    print("-" * 40)
    if failure_count == 0:
        print("STATUS: COMPLETE SUCCESS")
    else:
        print("STATUS: COMPLETED WITH ERRORS")
        if errors_log:
            print("Error Details:")
            for err in errors_log:
                print(f" - {err}")

# %% [markdown]
# #### Verification

# %%
def batch_verify_sheet1_variable_and_description_count_verbose(inventory, base_output_path, years=None):
    """
    Compare raw vs reshaped metadata counts for assurance.
    Returns a DataFrame with PASS/FAIL per year/month.
    """
    results = []
    reshaped_folder = os.path.join(base_output_path, "data", "interim", "NEW_metadata_sheet1")

    years_to_process = years if years else inventory.keys()

    for year in years_to_process:
        for month, files_list in inventory[year].items():
            if month == "Unmatched":
                continue

            try:
                raw_df = load_dataset(year, month, "metadata", sheet_number=0)
            except Exception as e:
                print(f"[ERROR] {month} {year}: Could not load raw Sheet 1 ({e})")
                continue

            reshaped_file_path = os.path.join(reshaped_folder, year, f"Sheet1_{month}_{year}.csv")
            if not os.path.exists(reshaped_file_path):
                print(f"[ERROR] {month} {year}: Reshaped CSV missing!")
                continue

            reshaped_df = pd.read_csv(reshaped_file_path)

            raw_vars = raw_df.iloc[:,4].dropna().astype(str).str.strip()
            raw_vars = raw_vars[raw_vars != '']
            raw_descs = raw_df.iloc[:,5].dropna().astype(str).str.strip()
            raw_descs = raw_descs[raw_descs != '']

            reshaped_vars = reshaped_df['Variable'].astype(str).str.strip()
            reshaped_vars = reshaped_vars[reshaped_vars != '']
            reshaped_descs = reshaped_df['Description'].astype(str).str.strip()
            reshaped_descs = reshaped_descs[reshaped_descs != '']

            status = "PASS" if (len(raw_vars) == len(reshaped_vars) and len(raw_descs) == len(reshaped_descs)) else "FAIL"
            if status == "FAIL":
                print(f"[MISMATCH] {month} {year} - Variables: {len(raw_vars)} vs {len(reshaped_vars)}, "
                      f"Descriptions: {len(raw_descs)} vs {len(reshaped_descs)}")

            results.append({
                'Year': year, 'Month': month,
                'Raw Variable Count': len(raw_vars),
                'Reshaped Variable Count': len(reshaped_vars),
                'Raw Description Count': len(raw_descs),
                'Reshaped Description Count': len(reshaped_descs),
                'Status': status
            })

    df = pd.DataFrame(results).sort_values(['Year', 'Month']).reset_index(drop=True)
    return df

# %% [markdown]
# #### Run batch and verify  (2018 trial)

# %%
# Trial run: process only 2018 locally (fast, avoids Drive write)
batch_process_sheet1_metadata(inventory, ".", years=["2018"])

# Verify outputs for 2018
verification_df = batch_verify_sheet1_variable_and_description_count_verbose(inventory, ".", years=["2018"])

print("=== Verification Results (Local) ===")
display(verification_df)
# Out:
# --- STARTING BATCH PROCESS ---
# Target Directory: .\data\interim\NEW_metadata_sheet1
# --------------------------------------------------
# [OK] Saved: 2018/Sheet1_April_2018.csv
# [OK] Saved: 2018/Sheet1_July_2018.csv
# [OK] Saved: 2018/Sheet1_January_2018.csv
# [OK] Saved: 2018/Sheet1_October_2018.csv
#
# === PROCESSING SUMMARY REPORT ===
# Total Successfully Saved: 4
# Total Failed:             0
# Total Skipped (No File):  0
# ----------------------------------------
# STATUS: COMPLETE SUCCESS
# === Verification Results (Local) ===
#    Year    Month  Raw Variable Count  Reshaped Variable Count  \
# 0  2018    April                  50                       50
# 1  2018  January                  50                       50
# 2  2018     July                  51                       51
# 3  2018  October                  51                       51
#
#    Raw Description Count  Reshaped Description Count Status
# 0                     50                          50   PASS
# 1                     50                          50   PASS
# 2                     51                          51   PASS
# 3                     51                          51   PASS

# %%
# Load the reshaped January 2018 metadata (Sheet 1) from the saved CSV
reshaped_jan_2018 = pd.read_csv(INTERIM_DIR / "NEW_metadata_sheet1" / "2018" / "Sheet1_January_2018.csv")

print("=== January 2018 Metadata Sheet 1 (Reshaped) ===")
display(reshaped_jan_2018.head(10))
# Out:
# === January 2018 Metadata Sheet 1 (Reshaped) ===
#      Variable                                        Description
# 0      PUFREG                                             Region
# 1      PUFPRV                                           Province
# 2    PUFPRRCD                                    Province Recode
# 3    PUFHHNUM                 Household Unique Sequential Number
# 4  PUFURB2K10                                2010Urban-RuralFIES
# 5  PUFPWGTPRV  Final Weight Based on Projection (provincial p...
# 6    PUFSVYMO                                       Survey Month
# 7    PUFSVYYR                                        Survey Year
# 8      PUFPSU                                         Psu Number
# 9      PUFRPL                                          Replicate

# %% [markdown]
# #### Batch Automation (Redirect to Drive/Base_path as new folder)

# %%
def batch_process_sheet1_metadata_to_drive(inventory, base_output_path, years=None):
    """
    Process metadata Sheet 1 for selected years.
    Saves reshaped CSVs directly into NEW Metadata Sheet 1 CSV's in Google Drive.
    Prints a progress report while running.
    """
    success_count, failure_count, skipped_count = 0, 0, 0
    errors_log = []

    main_folder_name = "NEW Metadata Sheet 1 CSV's"
    main_folder_path = os.path.join(base_output_path, main_folder_name)
    os.makedirs(main_folder_path, exist_ok=True)

    # Count total tasks for progress tracking
    total_tasks = sum(
        1 for year in (years if years else inventory.keys())
        for month, files_list in inventory[year].items()
        if any(f.get('filetype') == 'metadata' for f in files_list)
    )
    current_task = 0

    print("--- STARTING BATCH PROCESS TO DRIVE ---")
    print(f"Target Directory: {main_folder_path}")
    print("-" * 50)

    years_to_process = years if years else inventory.keys()

    for year in years_to_process:
        year_folder_path = os.path.join(main_folder_path, year)
        os.makedirs(year_folder_path, exist_ok=True)

        for month, files_list in inventory[year].items():
            if month == "Unmatched":
                continue

            has_metadata = any(f.get('filetype') == 'metadata' for f in files_list)
            if not has_metadata:
                skipped_count += 1
                continue

            current_task += 1
            try:
                raw_df = load_dataset(year, month, "metadata", 0)
                clean_df = extract_variables(raw_df)

                filename = f"Sheet1_{month}_{year}.csv"
                full_save_path = os.path.join(year_folder_path, filename)
                clean_df.to_csv(full_save_path, index=False)

                print(f"[{current_task}/{total_tasks}] [OK] Saved: {year}/{filename}")
                success_count += 1

            except Exception as e:
                print(f"[{current_task}/{total_tasks}] [ERROR] Failed {month} {year}: {e}")
                errors_log.append(f"{month} {year}: {str(e)}")
                failure_count += 1

    print("\n=== PROCESSING SUMMARY REPORT ===")
    print(f"Total Successfully Saved: {success_count}")
    print(f"Total Failed:             {failure_count}")
    print(f"Total Skipped (No File):  {skipped_count}")
    print("-" * 40)
    if failure_count == 0:
        print("STATUS: COMPLETE SUCCESS")
        print(f"All files are now located in: {main_folder_path}")
    else:
        print("STATUS: COMPLETED WITH ERRORS")
        if errors_log:
            print("Error Details:")
            for err in errors_log:
                print(f" - {err}")

# %%
# Run batch process for ALL years, saving directly to Drive
batch_process_sheet1_metadata_to_drive(inventory, str(BASE_PATH))
# Out:
# --- STARTING BATCH PROCESS TO DRIVE ---
# Target Directory: G:\.shortcut-targets-by-id\1VctTphaltRx4xcPxmTJlRTrxLalyuEt8\Labor Force Survey\NEW Metadata Sheet 1 CSV's
# --------------------------------------------------
# [1/40] [OK] Saved: 2018/Sheet1_April_2018.csv
print("=== January 2018 Metadata Sheet 2 (Raw) ===")
display(january_2018_metadata_sheet2.head(10))
# Out:
# === January 2018 Metadata Sheet 2 (Raw) ===
#   PUFREG_VS1 Region                        Unnamed: 2 Unnamed: 3  Unnamed: 4  \
# 0        NaN    NaN           National Capital Region         13         NaN
# 1        NaN    NaN  Cordillera Administrative Region         14         NaN
# 2        NaN    NaN          Region I - Ilocos Region          1         NaN
# 3        NaN    NaN        Region II - Cagayan Valley          2         NaN
# 4        NaN    NaN        Region III - Central Luzon          3         NaN
# 5        NaN    NaN           Region IVA - CALABARZON          4         NaN
# 6        NaN    NaN             Region IVB - MIMAROPA         17         NaN
# 7        NaN    NaN                   Region V- Bicol          5         NaN
# 8        NaN    NaN       Region VI - Western Visayas          6         NaN
# 9        NaN    NaN      Region VII - Central Visayas          7         NaN
#
#   Unnamed: 5
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# 5        NaN
# 6        NaN
# 7        NaN
# 8        NaN
# 9        NaN

# %% [markdown]
# ### Sheet 2 Metadata Reshape Automation

# %%
def reshape_sheet2_robust(df):
    """
    Convert metadata Sheet 2 (values dictionary) into clean long format.
    Carries forward variable name/description, fills blanks, and defaults min/max/extra to '0'.
    """
    reshaped = []
    df = df.fillna('').astype(str)

    current_var = df.iloc[0, 0].strip() or 'UNKNOWN_VAR'
    current_desc = df.iloc[0, 1].strip() or ''

    for _, row in df.iterrows():
        # Variable name
        if row.iloc[0].strip():
            current_var = row.iloc[0].strip()
        # Description
        if row.iloc[1].strip():
            current_desc = row.iloc[1].strip()

        raw_min = row.iloc[3].strip() if len(row) > 3 else ''
        raw_max = row.iloc[4].strip() if len(row) > 4 else ''

        # Extra values (col F+)
        extra = '0'
        if len(row) > 5:
            for j in range(5, len(row)):
                extra_candidate = row.iloc[j].strip()
                if extra_candidate:
                    extra = extra_candidate
                    break

        label = row.iloc[2].strip()

        if not label:
            if raw_min or raw_max or extra != '0':
                label = '0'
            else:
                continue

        min_value = raw_min if raw_min else '0'
        max_value = raw_max if raw_max else '0'

        reshaped.append({
            "Variable": current_var,
            "Description": current_desc,
            "Label": label,
            "min_value": min_value,
            "max_value": max_value,
            "additional_value": extra
        })

    return pd.DataFrame(reshaped)

# %% [markdown]
# #### Update Loader

# %%
def load_dataset(year, month, filetype="survey", sheet_number=None):
    file_info = next((f for f in inventory[year][month] if f["filetype"] == filetype), None)
    if not file_info:
        raise ValueError(f"No {filetype} file found for {month} {year}")

    file_path = BASE_PATH / year / file_info["filename"]

    if filetype == "survey":
        return pd.read_csv(file_path, low_memory=False)

    df = pd.read_excel(file_path, sheet_name=sheet_number, header=None)

    if sheet_number == 1:
        return reshape_sheet2_robust(df)
    return df

# %% [markdown]
# #### Batch process

# %%
import os
import pandas as pd

def batch_process_sheet2_metadata(inventory, base_output_path=".", years=None, mode="trial"):
    """
    Process metadata Sheet 2 (Value Codes) for selected years.
    Saves reshaped CSVs into:
      - mode="trial": data/interim/NEW_metadata_sheet2
      - mode="drive": NEW Metadata Sheet 2 CSV's
    Prints a progress report while running.
    """
    assert mode in {"trial", "drive"}, "mode must be 'trial' or 'drive'"

    # Choose target folder
    if mode == "trial":
        main_folder_path = os.path.join(base_output_path, "data", "interim", "NEW_metadata_sheet2")
        header = "--- STARTING BATCH PROCESS (SHEET 2, TRIAL: LOCAL INTERIM) ---"
    else:
        main_folder_path = os.path.join(base_output_path, "NEW Metadata Sheet 2 CSV's")
        header = "--- STARTING BATCH PROCESS (SHEET 2, DRIVE) ---"

    os.makedirs(main_folder_path, exist_ok=True)

    success_count, failure_count, skipped_count = 0, 0, 0
    errors_log = []

    years_to_process = years if years else inventory.keys()
    total_tasks = sum(
        1 for year in years_to_process
        for month, files_list in inventory[year].items()
        if month != "Unmatched" and any(f.get('filetype') == 'metadata' for f in files_list)
    )
    current_task = 0

    print(header)
    print(f"Target Directory: {main_folder_path}")
    print("-" * 50)

    for year in years_to_process:
        year_folder_path = os.path.join(main_folder_path, year)
        os.makedirs(year_folder_path, exist_ok=True)

        for month, files_list in inventory[year].items():
            if month == "Unmatched":
                continue

            if not any(f.get('filetype') == 'metadata' for f in files_list):
                skipped_count += 1
                continue

            current_task += 1
            try:
                clean_df = load_dataset(year, month, "metadata", sheet_number=1)

                filename = f"Sheet2_{month}_{year}.csv"
                full_save_path = os.path.join(year_folder_path, filename)
                clean_df.to_csv(full_save_path, index=False)

                print(f"[{current_task}/{total_tasks}] [OK] Saved: {year}/{filename}")
                success_count += 1

            except Exception as e:
                print(f"[{current_task}/{total_tasks}] [ERROR] Failed {month} {year}: {e}")
                errors_log.append(f"{month} {year}: {str(e)}")
                failure_count += 1

    print("\n=== SHEET 2 PROCESSING SUMMARY REPORT ===")
    print(f"Total Successfully Saved: {success_count}")
    print(f"Total Failed:             {failure_count}")
    print(f"Total Skipped (No File):  {skipped_count}")
    print("-" * 40)
    if failure_count == 0:
        print("STATUS: COMPLETE SUCCESS")
        print(f"All files are now located in: {main_folder_path}")
    else:
        print("STATUS: COMPLETED WITH ERRORS")
        for err in errors_log:
            print(f" - {err}")

# %% [markdown]
# #### Verification

# %%
def batch_verify_sheet2_counts(inventory, base_output_path=".", years=None, mode="trial"):
    """
    Verify Sheet 2 metadata reshaped files.
    mode="trial": looks in data/interim/NEW_metadata_sheet2
    mode="drive": looks in NEW Metadata Sheet 2 CSV's
    """
    assert mode in {"trial", "drive"}, "mode must be 'trial' or 'drive'"

    reshaped_folder = (
        os.path.join(base_output_path, "data", "interim", "NEW_metadata_sheet2")
        if mode == "trial"
        else os.path.join(base_output_path, "NEW Metadata Sheet 2 CSV's")
    )

    results = []
    years_to_process = years if years else inventory.keys()

    print(f"--- STARTING SHEET 2 VERIFICATION ({mode.upper()}) ---")
    print(f"Looking in: {reshaped_folder}")
    print("-" * 50)

    for year in years_to_process:
        for month, files_list in inventory[year].items():
            if month == "Unmatched":
                continue

            try:
                raw_df = pd.read_excel(BASE_PATH / year / next(f["filename"] for f in files_list if f["filetype"]=="metadata"),
                                       sheet_name=1, header=None)
            except Exception as e:
                print(f"[ERROR] {month} {year}: Could not load raw Sheet 2 ({e})")
                continue

            reshaped_file_path = os.path.join(reshaped_folder, year, f"Sheet2_{month}_{year}.csv")
            if not os.path.exists(reshaped_file_path):
                print(f"[ERROR] {month} {year}: Reshaped CSV missing!")
                continue

            reshaped_df = pd.read_csv(reshaped_file_path)

            raw_rows = len(raw_df.dropna(how="all"))
            reshaped_rows = len(reshaped_df.dropna(how="all"))
            status = "PASS" if reshaped_rows > 0 else "FAIL"

            print(f"[{status}] {month} {year} - Raw rows: {raw_rows}, Reshaped rows: {reshaped_rows}")

            results.append({
                'Year': year, 'Month': month,
                'Raw Row Count': raw_rows,
                'Reshaped Row Count': reshaped_rows,
                'Status': status
            })

    df = pd.DataFrame(results).sort_values(['Year', 'Month']).reset_index(drop=True)

    print("\n=== SHEET 2 VERIFICATION SUMMARY ===")
    print(f"Total Files Checked: {len(df)}")
    print(f"PASS: {len(df[df['Status']=='PASS'])}")
    print(f"FAIL: {len(df[df['Status']=='FAIL'])}")
    print("-" * 40)

    return df

# %% [markdown]
# #### Run batch and verify  (2018 trial)

# %%
# Trial run: process only 2018 locally (fast, avoids Drive write)
batch_process_sheet2_metadata(inventory, ".", years=["2018"], mode="trial")

# Verify outputs for 2018
verification_df_sheet2 = batch_verify_sheet2_counts(inventory, ".", years=["2018"], mode="trial")

print("=== Verification Results (Sheet 2, Local) ===")
display(verification_df_sheet2)
# Out:
# --- STARTING BATCH PROCESS (SHEET 2, TRIAL: LOCAL INTERIM) ---
# Target Directory: .\data\interim\NEW_metadata_sheet2
# --------------------------------------------------
# [1/4] [OK] Saved: 2018/Sheet2_April_2018.csv
# [2/4] [OK] Saved: 2018/Sheet2_July_2018.csv
# [3/4] [OK] Saved: 2018/Sheet2_January_2018.csv
# [4/4] [OK] Saved: 2018/Sheet2_October_2018.csv
#
# === SHEET 2 PROCESSING SUMMARY REPORT ===
# Total Successfully Saved: 4
# Total Failed:             0
# Total Skipped (No File):  0
# ----------------------------------------
# STATUS: COMPLETE SUCCESS
# All files are now located in: .\data\interim\NEW_metadata_sheet2
# --- STARTING SHEET 2 VERIFICATION (TRIAL) ---
# Looking in: .\data\interim\NEW_metadata_sheet2
# --------------------------------------------------
# [PASS] April 2018 - Raw rows: 409, Reshaped rows: 366
# [PASS] July 2018 - Raw rows: 342, Reshaped rows: 298
# [PASS] January 2018 - Raw rows: 444, Reshaped rows: 398
# [PASS] October 2018 - Raw rows: 458, Reshaped rows: 406
#
# === SHEET 2 VERIFICATION SUMMARY ===
# Total Files Checked: 4
# PASS: 4
# FAIL: 0
# ----------------------------------------
# === Verification Results (Sheet 2, Local) ===
#    Year    Month  Raw Row Count  Reshaped Row Count Status
# 0  2018    April            409                 366   PASS
# 1  2018  January            444                 398   PASS
# 2  2018     July            342                 298   PASS
# 3  2018  October            458                 406   PASS

# %% [markdown]
# #### Batch Automation (Redirect to Drive/Base_path as new folder)

# %%
batch_process_sheet2_metadata(inventory, str(BASE_PATH), mode="drive")
verification_df_sheet2_drive = batch_verify_sheet2_counts(inventory, str(BASE_PATH), mode="drive")
# Out:
# --- STARTING BATCH PROCESS (SHEET 2, DRIVE) ---
# --- STARTING SHEET 2 VERIFICATION (DRIVE) ---
# Looking in: G:\.shortcut-targets-by-id\1VctTphaltRx4xcPxmTJlRTrxLalyuEt8\Labor Force Survey\NEW Metadata Sheet 2 CSV's
# --------------------------------------------------
# [PASS] April 2018 - Raw rows: 409, Reshaped rows: 366
# [PASS] July 2018 - Raw rows: 342, Reshaped rows: 298
# [PASS] January 2018 - Raw rows: 444, Reshaped rows: 398
# [PASS] October 2018 - Raw rows: 458, Reshaped rows: 406
# [PASS] April 2019 - Raw rows: 1114, Reshaped rows: 1069
# [PASS] July 2019 - Raw rows: 385, Reshaped rows: 329
# [PASS] October 2019 - Raw rows: 385, Reshaped rows: 329
# [PASS] January 2019 - Raw rows: 364, Reshaped rows: 320
# [PASS] July 2022 - Raw rows: 2116, Reshaped rows: 2059
# [PASS] June 2022 - Raw rows: 2056, Reshaped rows: 2010
# [PASS] April 2022 - Raw rows: 2115, Reshaped rows: 2058
# [PASS] August 2022 - Raw rows: 2056, Reshaped rows: 2010
# [PASS] December 2022 - Raw rows: 2056, Reshaped rows: 2010
# [PASS] February 2022 - Raw rows: 2044, Reshaped rows: 1999
# [PASS] January 2022 - Raw rows: 2115, Reshaped rows: 2058
# [PASS] March 2022 - Raw rows: 2044, Reshaped rows: 1999
# [PASS] May 2022 - Raw rows: 2056, Reshaped rows: 2010
# [PASS] November 2022 - Raw rows: 2056, Reshaped rows: 2010
# [PASS] October 2022 - Raw rows: 2116, Reshaped rows: 2059
# [PASS] September 2022 - Raw rows: 2058, Reshaped rows: 2011
# [PASS] April 2023 - Raw rows: 2111, Reshaped rows: 2059
# [PASS] August 2023 - Raw rows: 2051, Reshaped rows: 2010
# [PASS] December 2023 - Raw rows: 2049, Reshaped rows: 2009
# [PASS] February 2023 - Raw rows: 2052, Reshaped rows: 2011
# [PASS] January 2023 - Raw rows: 2112, Reshaped rows: 2060
# [PASS] July 2023 - Raw rows: 2106, Reshaped rows: 2055
# [PASS] June 2023 - Raw rows: 2052, Reshaped rows: 2011
# [PASS] March 2023 - Raw rows: 2052, Reshaped rows: 2011
# [PASS] November 2023 - Raw rows: 2049, Reshaped rows: 2009
# [PASS] October 2023 - Raw rows: 2114, Reshaped rows: 2062
# [PASS] September 2023 - Raw rows: 2049, Reshaped rows: 2009
# [PASS] May 2023 - Raw rows: 2052, Reshaped rows: 2011
# [PASS] February 2024 - Raw rows: 2050, Reshaped rows: 2010
# [PASS] April 2024 - Raw rows: 2095, Reshaped rows: 2044
# [PASS] January 2024 - Raw rows: 2399, Reshaped rows: 2347
# [PASS] August 2024 - Raw rows: 2049, Reshaped rows: 2010
# [PASS] July 2024 - Raw rows: 2114, Reshaped rows: 2063
# [PASS] March 2024 - Raw rows: 2050, Reshaped rows: 2010
# [PASS] May 2024 - Raw rows: 2036, Reshaped rows: 1995
# [PASS] June 2024 - Raw rows: 2034, Reshaped rows: 1994
#
# === SHEET 2 VERIFICATION SUMMARY ===
# Total Files Checked: 40
# PASS: 40
# FAIL: 0
# ----------------------------------------
