# %% [markdown]
# ### Recalling consistent variables throughout the datasets

# %%
import os
import pandas as pd

# Base path where decoded surveys are stored
base_path = r"G:\.shortcut-targets-by-id\1VctTphaltRx4xcPxmTJlRTrxLalyuEt8\Labor Force Survey\Fully Decoded Surveys"

# Years to inspect
years = [str(y) for y in range(2018, 2025)]

# Dictionary to store variables per year
vars_per_year = {}

for year in years:
    year_folder = os.path.join(base_path, year)
    if not os.path.isdir(year_folder):
        continue
    
    cols_this_year = set()
    for file in os.listdir(year_folder):
        if file.endswith(".CSV"):
            df = pd.read_csv(os.path.join(year_folder, file), nrows=10)  # read only first 10 rows for speed
            cols_this_year.update(df.columns.tolist())
    
    vars_per_year[year] = cols_this_year
    print(f"[OK] {year}: {len(cols_this_year)} variables detected.")

# Find variables consistent across all years
consistent_vars = set.intersection(*vars_per_year.values())

print("\n===============================================")
print("CONSISTENT VARIABLES ACROSS 2018–2024")
print("===============================================\n")
for var in sorted(consistent_vars):
    print(var)

print(f"\nTotal consistent variables: {len(consistent_vars)}")
# Out:
# [OK] 2018: 54 variables detected.
# [OK] 2019: 50 variables detected.
# [OK] 2022: 78 variables detected.
# [OK] 2023: 81 variables detected.
# [OK] 2024: 79 variables detected.
#
# ===============================================
# CONSISTENT VARIABLES ACROSS 2018–2024
# ===============================================
#
# C03-Relationship to Household Head
# C04-Sex
# C05-Age as of Last Birthday
# C06-Marital Status
# C07-Highest Grade Completed
# C08-Currently Attending School
# C09-Graduate of technical/vocational course
# C09a - Currently Attending Non-formal Training for Skills Development
# C10-Overseas Filipino Indicator
# C101-Line Number
# C11-Work Indicator
# C12-Job Indicator
# C14-Primary Occupation
# C16-Kind of Business (Primary Occupation)
# C17-Nature of Employment (Primary Occupation)
# C18-Normal Working Hours per Day
# C19-Total Number of Hours Worked during the past week
# C20-Want More Hours of Work
# C21-Look for Additional Work
# C22-First Time to Work
# C23-Class of Worker (Primary Occupation)
# C24-Basis of Payment (Primary Occupation)
# C25-Basic Pay per Day (Primary Occupation)
# C26-Other Job Indicator
# C27-Number of Jobs during the past week
# C28-Total Hours Worked for all Jobs
# C29-Reasons for Working More than 48 Hours during the past week
# C30-Looked for Work or Tried to Establish Business during the past week
# C31-First Time to Look for Work
# C32-Job Search Method
# C33-Number of Weeks Spent in Looking for Work
# C34-Reason for not Looking for Work
# C35-When Last Looked for Work
# C36-Available for Work
# C37-Willingness to take up work during the past week or withing two weeks
# C38-Previous Job Indicator
# C43-Kind of Business (past quarter)
# Household Size
# Household Unique Sequential Number
# New Employment Criteria (jul 05, 2005)
# Psu Number
# Region
# Replicate
# Survey Month
# Survey Year
#
# Total consistent variables: 45

# %% [markdown]
# ### Recall FMI Summary Results

# %%
import os
import pandas as pd

# Define your base path again in this notebook
base_path = r"G:\.shortcut-targets-by-id\1VctTphaltRx4xcPxmTJlRTrxLalyuEt8\Labor Force Survey"

# Point to the *new* FMI Reports folder
reports_root = os.path.join(base_path, "New FMI Reports")

# Path to the saved overall summary file
summary_path = os.path.join(reports_root, "FMI_Summary_2018_2024.csv")

# Load the summary
FMI_summary = pd.read_csv(summary_path)

# Inspect results
FMI_summary.head()
# Out:
#                                                Column  TotalMissing  \
# 0                  C03-Relationship to Household Head             0
# 1                                             C04-Sex             0
# 2                         C05-Age as of Last Birthday         82751
# 3                                    C05B - Ethnicity             0
# 4                                  C06-Marital Status        358820
# 5                         C07-Highest Grade Completed        361914
# 6                      C08-Currently Attending School       2281910
# 7                     C08-Overseas Filipino Indicator        203920
# 8         C09-Graduate of technical/vocational course       1162929
# 9                                  C09-Work Indicator         64311
# 10                              C09A-Work Arrangement        268713
# 11                                C09A-Work Indicator        150866
# 12  C09a - Currently Attending Non-formal Training...       1051509
# 13                                  C10-Job Indicator        409351
# 14                    C10-Overseas Filipino Indicator       1162929
# 15                                   C101-Line Number         42235
# 16                                 C11-Work Indicator        375100
# 17                         C11A - Working Arrangement       1551120
# 18                                  C12-Job Indicator       2071068
# 19                         C13-Major Occupation Group        416222
# 20                             C14-Primary Occupation       2409128
# 21                           C15-Major Industry Group        416222
# 22          C16-Kind of Business (Primary Occupation)       2409128
# 23      C16-Nature of Employment (Primary Occupation)        419786
# 24      C17-Nature of Employment (Primary Occupation)       2423329
# 25  C18-Total Number of Hours Worked during the pa...        419786
# 26  C19-Total Number of Hours Worked during the pa...       2422541
# 27           C19B - Time of work during the past week         99990
# 28                   C20B - First time to do any work        419786
# 29           C21-Class of Worker (Primary Occupation)        419786
# 30                             C22-First Time to Work       2423330
# 31           C23-Class of Worker (Primary Occupation)       2420727
# 32          C24-Basis of Payment (Primary Occupation)       3090303
# 33  C24-Reasons for Working More than 48 Hours dur...        586735
# 34         C25-Basic Pay per Day (Primary Occupation)       3229562
# 35                C26-Reason for not Looking for Work        570516
# 36                             C27-Available for Work        742224
# 37            C27-Number of Jobs during the past week       3969850
# 38                          C29 - Last worked (Month)        664028
# 39                           C29 - Last worked (Year)        664028
# 40  C29-Reasons for Working More than 48 Hours dur...       3261931
# 41                              C32-Job Search Method       4074439
# 42         C33-Kind of Business (previous occupation)         37916
# 43      C33-Number of Weeks Spent in Looking for Work       4074488
# 44                C34-Reason for not Looking for Work       2963387
# 45                      C35-When Last Looked for Work       4073352
# 46                             C36-Available for Work       3970097
# 47  C37-Willingness to take up work during the pas...       3970097
# 48                          C39 - Last worked (Month)       2346568
# 49                           C39 - Last worked (Year)       2346568
#
#     TotalRows    AvgFMI  MonthsObserved  OverallFMI      Flag  \
# 0     4881364  0.000000              34    0.000000       Low
# 1     4881364  0.000000              34    0.000000       Low
# 2     4881364  0.019262              34    0.016952       Low
# 3      707981  0.000000               1    0.000000       Low
# 4     4881364  0.069921              34    0.073508  Moderate
# 5     4881364  0.071961              34    0.074142  Moderate
# 6     4116745  0.567432              17    0.554300  Critical
# 7      764619  0.266685              17    0.266695      High
# 8     4116745  0.285236              17    0.282487      High
# 9      764619  0.084135              17    0.084109  Moderate
# 10     488800  0.549719              11    0.549740  Critical
# 11     275819  0.546968               6    0.546975  Critical
# 12    3756668  0.282010              15    0.279905      High
# 13     764619  0.535387              17    0.535366  Critical
# 14    4116745  0.285236              17    0.282487      High
# 15    4881364  0.008199              34    0.008652       Low
# 16    4116745  0.093127              17    0.091116  Moderate
# 17    2687486  0.567196               9    0.577164  Critical
# 18    4116745  0.506553              17    0.503084  Critical
# 19     764619  0.544376              17    0.544352  Critical
# 20    4116745  0.583287              17    0.585202  Critical
# 21     764619  0.544376              17    0.544352  Critical
# 22    4116745  0.583287              17    0.585202  Critical
# 23     764619  0.549015              17    0.549013  Critical
# 24    4116745  0.587537              17    0.588652  Critical
# 25     764619  0.549015              17    0.549013  Critical
# 26    4116745  0.587284              17    0.588460  Critical
# 27     179173  0.558064               1    0.558064  Critical
# 28     764619  0.549015              17    0.549013  Critical
# 29     764619  0.549015              17    0.549013  Critical
# 30    4116745  0.587537              17    0.588652  Critical
# 31    4116745  0.586689              17    0.588020  Critical
# 32    4116745  0.753847              17    0.750667  Critical
# 33     764619  0.767586              17    0.767356  Critical
# 34    4116745  0.787998              17    0.784494  Critical
# 35     764619  0.746114              17    0.746144  Critical
# 36     764619  0.970756              17    0.970711  Critical
# 37    4116745  0.964375              17    0.964318  Critical
# 38     764619  0.868570              17    0.868443  Critical
# 39     764619  0.868570              17    0.868443  Critical
# 40    4116745  0.789809              17    0.792357  Critical
# 41    4116745  0.990070              17    0.989723  Critical
# 42      43375  0.874144               1    0.874144  Critical
# 43    4116745  0.990086              17    0.989735  Critical
# 44    4116745  0.724277              17    0.719837  Critical
# 45    4116745  0.990214              17    0.989459  Critical
# 46    4116745  0.965181              17    0.964378  Critical
# 47    4116745  0.965181              17    0.964378  Critical
# 48    2687486  0.868394               9    0.873146  Critical
# 49    2687486  0.868394               9    0.873146  Critical
#
#                                       Recommendation
# 0                                               Keep
# 1                                               Keep
# 2                                               Keep
# 3                                               Keep
# 4                                Consider imputation
# 5                                Consider imputation
# 6   Candidate to drop (validate with business logic)
# 7                       Strongly consider imputation
# 8                       Strongly consider imputation
# 9                                Consider imputation
# 10  Candidate to drop (validate with business logic)
# 11  Candidate to drop (validate with business logic)
# 12                      Strongly consider imputation
# 13  Candidate to drop (validate with business logic)
# 14                      Strongly consider imputation
# 15                                              Keep
# 16                               Consider imputation
# 17  Candidate to drop (validate with business logic)
# 18  Candidate to drop (validate with business logic)
# 19  Candidate to drop (validate with business logic)
# 20  Candidate to drop (validate with business logic)
# 21  Candidate to drop (validate with business logic)
# 22  Candidate to drop (validate with business logic)
# 23  Candidate to drop (validate with business logic)
# 24  Candidate to drop (validate with business logic)
# 25  Candidate to drop (validate with business logic)
# 26  Candidate to drop (validate with business logic)
# 27  Candidate to drop (validate with business logic)
# 28  Candidate to drop (validate with business logic)
# 29  Candidate to drop (validate with business logic)
# 30  Candidate to drop (validate with business logic)
# 31  Candidate to drop (validate with business logic)
# 32  Candidate to drop (validate with business logic)
# 33  Candidate to drop (validate with business logic)
# 34  Candidate to drop (validate with business logic)
# 35  Candidate to drop (validate with business logic)
# 36  Candidate to drop (validate with business logic)
# 37  Candidate to drop (validate with business logic)
# 38  Candidate to drop (validate with business logic)
# 39  Candidate to drop (validate with business logic)
# 40  Candidate to drop (validate with business logic)
# 41  Candidate to drop (validate with business logic)
# 42  Candidate to drop (validate with business logic)
# 43  Candidate to drop (validate with business logic)
# 44  Candidate to drop (validate with business logic)
# 45  Candidate to drop (validate with business logic)
# 46  Candidate to drop (validate with business logic)
# 47  Candidate to drop (validate with business logic)
# 48  Candidate to drop (validate with business logic)
# 49  Candidate to drop (validate with business logic)
